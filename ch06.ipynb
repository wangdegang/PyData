# %% [markdown]
# # Data Loading, Storage, and File Formats

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Reading and writing data in texas format

# %% [markdown]
# !cat example/ex1.csv
# a, b, c, d, message
# 1, 2, 3, 4, hello
# 5, 6, 7, 8, world
# 9, 10, 11, 12, foo

# %%
df = pd.read_csv('example/ex01.csv')
df = pd.read_table('example/ex01.csv' sep=',')
df = pd.read_csv('example/ex01.csv' header=None)
df = pd.read_Csv('example/ex02.csv', names=['a', 'b', 'c', 'd', 'message'])

# %%
pd.read_csv('examples/ex2.csv', names=names, index_col='message')

# %% [markdown]
# ## Reading text files in pieces

# %%
pd.read_csv('examples/ex6.csv', nrows=5)

# %%
chunker = pd.read_csv('examples/ex6.csv', chunksize=1000)    # 1000 roes each chunk

# %% [markdown]
# ## Writing data out to text format

# %%
df = pd.read_csv("example/ex01.csv")
df.t0_csv("exampe/out01.csv")
df.t0_csv("exampe/out01.csv", sep='|')
df.t0_csv("exampe/out01.csv", na_rep='NULL')  # denote missing values as "NULL"

df.to_csv("example/out01.csv", index=False, columns=['a', 'b'. 'c'])

# %% [markdown]
# ## Manually working with delimited formats

# %%
import csv
f = open("example/ex01.csv")

reader = csv.reader(f)

for line in reader:
    print(line)

# %%
lines = list(csv.reader(open('examples/ex7.csv')))
header, values = lines[0], lines[1:]
data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict

# %%
class my_dialect(csv.Dialect):
    lineterminator = '\n'
    delimiter = ';'
    quotechar = '"'
    quoting = csv.QUOTE_MINIMAL
    
reader = csv.reader(f, dialect=my_dialect)

# %%
with open('mydata.csv', 'w') as f:
    writer = csv.writer(f, dialect=my_dialect)
    writer.writerow(('one', 'two', 'three'))
    writer.writerow(('1', '2', '3'))
    writer.writerow(('4', '5', '6'))
    writer.writerow(('7', '8', '9'))

# %% [markdown]
# ## JSON data

# %%
obj = """
{"name": "Wes",
"places_lived": ["United States", "Spain", "Germany"],
"pet": null,
"siblings": [{"name": "Scott", "age": 29, "pets": ["Zeus", "Zuko"]},
{"name": "Katie", "age": 38,
"pets": ["Sixes", "Stache", "Cisco"]}]
}"
""

# %%
import json
result = json.loads(obj)

# %%
asjson = json.dumps(pythonObj)
pd.read_json("example/out01.json")

# %% [markdown]
# ## XML and HTML: web scapting

# %% [markdown]
# ## Binary Data Formats

# %%
frame = pd.read_csv('examples/ex1.csv')
frame.to_pickle('examples/frame_pickle')
pd.read_pickle('examples/frame_pickle')

# %% [markdown]
# ### HDF5

# %% [markdown]
# ### MS Excel files

# %%
xlsx = pd.ExcelFile('examples/ex1.xlsx')
pd.read_excel(xlsx, 'Sheet1')

pd.read_excel('examples/ex1.xlsx', 'Sheet1')

# %%
writer = pd.ExcelWriter('examples/ex2.xlsx')
frame.to_excel(writer, 'Sheet1')
writer.save()

# %% [markdown]
# ## Interacting with web APIs

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data
# Out:
# [{'assignee': None,
#   'assignees': [],
#   'author_association': 'NONE',
#   'body': "#### Code Sample, a copy-pastable example if possible\r\n\r\n```python\r\nimport pandas as pd\r\nimport numpy as np\r\n\r\ns = pd.Series([float('nan')])\r\nt = s.fillna(2 ** 63)         # RuntimeError: maximum recursion depth exceeded in cmp\r\nt = s.fillna(float(2 ** 63))  # works\r\n```\r\n#### Problem description\r\n\r\nA `fillna` call with a large integer causes infinite recursion. Converting to a float before passing it in seems to fix it. Maybe the arg of `fillna` should be converted to the series dtype immediately?\r\n\r\nNote that this bug only affects PY2, PY3 works just fine.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit: None\r\npython: 2.7.14.final.0\r\npython-bits: 64\r\nOS: Linux\r\nOS-release: 3.x.x...x86_64\r\nmachine: x86_64\r\nprocessor: x86_64\r\nbyteorder: little\r\nLC_ALL: None\r\nLANG: en_US.UTF-8\r\nLOCALE: None.None\r\n\r\npandas: 0.21.0\r\npytest: 3.2.3\r\npip: 9.0.1\r\nsetuptools: 36.6.0\r\nCython: 0.27.3\r\nnumpy: 1.13.3\r\nscipy: 1.0.0\r\npyarrow: None\r\nxarray: None\r\nIPython: 5.4.1\r\nsphinx: None\r\npatsy: 0.4.1\r\ndateutil: 2.6.1\r\npytz: 2017.3\r\nblosc: None\r\nbottleneck: None\r\ntables: 3.4.2\r\nnumexpr: 2.6.4\r\nfeather: None\r\nmatplotlib: 2.1.0\r\nopenpyxl: None\r\nxlrd: None\r\nxlwt: None\r\nxlsxwriter: None\r\nlxml: None\r\nbs4: None\r\nhtml5lib: 0.999999999\r\nsqlalchemy: 1.1.15\r\npymysql: None\r\npsycopg2: 2.7.3.2 (dt dec pq3 ext)\r\njinja2: 2.9.6\r\ns3fs: None\r\nfastparquet: None\r\npandas_gbq: None\r\npandas_datareader: 0.5.0\r\n\r\n</details>\r\n",
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18159/comments',
#   'created_at': '2017-11-08T00:11:37Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18159/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/18159',
#   'id': 272030842,
#   'labels': [],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18159/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'number': 18159,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'BUG: fillna maximum recursion depth exceeded in cmp',
#   'updated_at': '2017-11-08T00:11:37Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18159',
#   'user': {'avatar_url': 'https://avatars2.githubusercontent.com/u/51099?v=4',
#    'events_url': 'https://api.github.com/users/llchan/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/llchan/followers',
#    'following_url': 'https://api.github.com/users/llchan/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/llchan/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/llchan',
#    'id': 51099,
#    'login': 'llchan',
#    'organizations_url': 'https://api.github.com/users/llchan/orgs',
#    'received_events_url': 'https://api.github.com/users/llchan/received_events',
#    'repos_url': 'https://api.github.com/users/llchan/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/llchan/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/llchan/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/llchan'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': 'try reg dateutil install\r\n',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18157/comments',
#   'created_at': '2017-11-07T21:13:26Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18157/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/18157',
#   'id': 271985388,
#   'labels': [{'color': 'a2bca7',
#     'default': False,
#     'id': 48070600,
#     'name': 'CI',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18157/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'number': 18157,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/18157.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/18157',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/18157.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/18157'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': "WIP/CI: don't show miniconda output on install",
#   'updated_at': '2017-11-07T21:40:52Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18157',
#   'user': {'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#    'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/jreback/followers',
#    'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/jreback',
#    'id': 953992,
#    'login': 'jreback',
#    'organizations_url': 'https://api.github.com/users/jreback/orgs',
#    'received_events_url': 'https://api.github.com/users/jreback/received_events',
#    'repos_url': 'https://api.github.com/users/jreback/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/jreback'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': '#### Code Sample, a copy-pastable example if possible\r\n\r\n```python\r\nIn [7]: pd.DataFrame.to_parquet?\r\nSignature: pd.DataFrame.to_parquet(self, fname, engine=\'auto\', compression=\'snappy\', **kwargs)\r\nDocstring:\r\nWrite a DataFrame to the binary parquet format.\r\n\r\n.. versionadded:: 0.21.0\r\n\r\nParameters\r\n----------\r\nfname : str\r\n    string file path\r\nengine : {\'auto\', \'pyarrow\', \'fastparquet\'}, default \'auto\' <--- here\r\n```\r\n\r\nbut with `auto`:\r\n\r\n```python\r\n\r\nIn [9]: pd.DataFrame([1,2,3]).to_parquet(\'f\', engine=\'auto\')\r\n---------------------------------------------------------------------------\r\nValueError                                Traceback (most recent call last)\r\n<ipython-input-9-057ba592ccd7> in <module>()\r\n----> 1 pd.DataFrame([1,2,3]).to_parquet(\'f\', engine=\'auto\')\r\n\r\n/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in to_parquet(self, fname, engine, compression, **kwargs)\r\n   1647         from pandas.io.parquet import to_parquet\r\n   1648         to_parquet(self, fname, engine,\r\n-> 1649                    compression=compression, **kwargs)\r\n   1650\r\n   1651     @Substitution(header=\'Write out the column names. If a list of strings \'\r\n\r\n/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parquet.py in to_parquet(df, path, engine, compression, **kwargs)\r\n    140     """\r\n    141\r\n--> 142     impl = get_engine(engine)\r\n    143\r\n    144     if not isinstance(df, DataFrame):\r\n\r\n/Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/parquet.py in get_engine(engine)\r\n     27\r\n     28     if engine not in [\'pyarrow\', \'fastparquet\']:\r\n---> 29         raise ValueError("engine must be one of \'pyarrow\', \'fastparquet\'")\r\n     30\r\n     31     if engine == \'pyarrow\':\r\n\r\nValueError: engine must be one of \'pyarrow\', \'fastparquet\'\r\n```\r\n\r\n#### Problem description\r\n\r\nEither allow `auto` or don\'t have it in the docs & default\r\n\r\n#### Expected Output\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nIn [10]: pd.show_versions()\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit: None\r\npython: 3.6.1.final.0\r\npython-bits: 64\r\nOS: Darwin\r\nOS-release: 17.2.0\r\nmachine: x86_64\r\nprocessor: i386\r\nbyteorder: little\r\nLC_ALL: None\r\nLANG: en_US.UTF-8\r\nLOCALE: en_US.UTF-8\r\n\r\npandas: 0.21.0\r\npytest: 3.2.3\r\npip: 9.0.1\r\nsetuptools: 36.5.0\r\nCython: 0.27.1\r\nnumpy: 1.13.3\r\nscipy: 0.19.1\r\npyarrow: None\r\nxarray: 0.10.0rc1-2-gf83361c\r\nIPython: 6.2.1\r\nsphinx: None\r\npatsy: 0.4.1\r\ndateutil: 2.6.1\r\npytz: 2017.3\r\nblosc: None\r\nbottleneck: 1.2.1\r\ntables: None\r\nnumexpr: 2.6.4\r\nfeather: None\r\nmatplotlib: 2.0.2\r\nopenpyxl: None\r\nxlrd: None\r\nxlwt: 1.3.0\r\nxlsxwriter: None\r\nlxml: None\r\nbs4: None\r\nhtml5lib: 0.9999999\r\nsqlalchemy: 1.1.14\r\npymysql: None\r\npsycopg2: None\r\njinja2: 2.9.6\r\ns3fs: None\r\nfastparquet: None\r\npandas_gbq: 0.2.0+8.g9eb9d77\r\npandas_datareader: None\r\n</details>\r\n',
#   'closed_at': None,
#   'comments': 3,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18156/comments',
#   'created_at': '2017-11-07T20:19:00Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18156/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/18156',
#   'id': 271969420,
#   'labels': [{'color': 'fbca04',
#     'default': False,
#     'id': 29648920,
#     'name': 'Difficulty Novice',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Difficulty%20Novice'},
#    {'color': '006b75',
#     'default': False,
#     'id': 195648009,
#     'name': 'Effort Low',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Effort%20Low'},
#    {'color': 'ffa0ff',
#     'default': False,
#     'id': 42670965,
#     'name': 'Error Reporting',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Error%20Reporting'},
#    {'color': '5319e7',
#     'default': False,
#     'id': 685114413,
#     'name': 'IO Parquet',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Parquet'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18156/labels{/name}',
#   'locked': False,
#   'milestone': {'closed_at': None,
#    'closed_issues': 42,
#    'created_at': '2017-10-02T10:21:48Z',
#    'creator': {'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'gravatar_id': '',
#     'html_url': 'https://github.com/jreback',
#     'id': 953992,
#     'login': 'jreback',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'site_admin': False,
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'type': 'User',
#     'url': 'https://api.github.com/users/jreback'},
#    'description': '',
#    'due_on': '2017-11-30T08:00:00Z',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/52',
#    'id': 2806806,
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/52/labels',
#    'number': 52,
#    'open_issues': 21,
#    'state': 'open',
#    'title': '0.21.1',
#    'updated_at': '2017-11-07T20:56:44Z',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/52'},
#   'number': 18156,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': "Minor doc issue in to_parquet(engine='auto')",
#   'updated_at': '2017-11-07T20:53:32Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18156',
#   'user': {'avatar_url': 'https://avatars0.githubusercontent.com/u/5635139?v=4',
#    'events_url': 'https://api.github.com/users/MaximilianR/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/MaximilianR/followers',
#    'following_url': 'https://api.github.com/users/MaximilianR/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MaximilianR/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/MaximilianR',
#    'id': 5635139,
#    'login': 'MaximilianR',
#    'organizations_url': 'https://api.github.com/users/MaximilianR/orgs',
#    'received_events_url': 'https://api.github.com/users/MaximilianR/received_events',
#    'repos_url': 'https://api.github.com/users/MaximilianR/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/MaximilianR/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MaximilianR/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/MaximilianR'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'NONE',
#   'body': '- [ x ] closes #18154\r\n- [ x ] tests added / passed\r\n- [ x ] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [x] whatsnew entry',
#   'closed_at': None,
#   'comments': 2,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18155/comments',
#   'created_at': '2017-11-07T20:09:57Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18155/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/18155',
#   'id': 271966754,
#   'labels': [{'color': '4E9A06',
#     'default': False,
#     'id': 76812,
#     'name': 'Enhancement',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement'},
#    {'color': '5319e7',
#     'default': False,
#     'id': 685114413,
#     'name': 'IO Parquet',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Parquet'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18155/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'number': 18155,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/18155.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/18155',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/18155.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/18155'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'restrict columns to read for pandas.read_parquet',
#   'updated_at': '2017-11-07T21:17:48Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18155',
#   'user': {'avatar_url': 'https://avatars2.githubusercontent.com/u/7143?v=4',
#    'events_url': 'https://api.github.com/users/hoffmann/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/hoffmann/followers',
#    'following_url': 'https://api.github.com/users/hoffmann/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hoffmann/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/hoffmann',
#    'id': 7143,
#    'login': 'hoffmann',
#    'organizations_url': 'https://api.github.com/users/hoffmann/orgs',
#    'received_events_url': 'https://api.github.com/users/hoffmann/received_events',
#    'repos_url': 'https://api.github.com/users/hoffmann/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/hoffmann/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hoffmann/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/hoffmann'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'NONE',
#   'body': '#### Problem description\r\n\r\nIn pandas 0.21 the top level funtion read_parquet() was introduced. Both available engines fastparquet and pyarrow support the specifications of columns to read. If you are only interested in certain columns of a dataframe this reduces the io.\r\n\r\n- Fastparquet https://github.com/dask/fastparquet/blob/master/docs/source/quickstart.rst#reading\r\n\r\n- PyArrow http://pyarrow-xhochy.readthedocs.io/en/latest/pyarrow.parquet.html#pyarrow.parquet.read_table\r\n\r\nIt should be also possible to specify the columns in pandas.read_parquet().\r\n\r\n\r\n\r\n',
#   'closed_at': None,
#   'comments': 2,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18154/comments',
#   'created_at': '2017-11-07T20:08:35Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18154/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/18154',
#   'id': 271966313,
#   'labels': [{'color': 'fbca04',
#     'default': False,
#     'id': 29648920,
#     'name': 'Difficulty Novice',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Difficulty%20Novice'},
#    {'color': '006b75',
#     'default': False,
#     'id': 195648009,
#     'name': 'Effort Low',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Effort%20Low'},
#    {'color': '4E9A06',
#     'default': False,
#     'id': 76812,
#     'name': 'Enhancement',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement'},
#    {'color': '5319e7',
#     'default': False,
#     'id': 685114413,
#     'name': 'IO Parquet',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20Parquet'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18154/labels{/name}',
#   'locked': False,
#   'milestone': {'closed_at': None,
#    'closed_issues': 42,
#    'created_at': '2017-10-02T10:21:48Z',
#    'creator': {'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'gravatar_id': '',
#     'html_url': 'https://github.com/jreback',
#     'id': 953992,
#     'login': 'jreback',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'site_admin': False,
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'type': 'User',
#     'url': 'https://api.github.com/users/jreback'},
#    'description': '',
#    'due_on': '2017-11-30T08:00:00Z',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/52',
#    'id': 2806806,
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/52/labels',
#    'number': 52,
#    'open_issues': 21,
#    'state': 'open',
#    'title': '0.21.1',
#    'updated_at': '2017-11-07T20:56:44Z',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/52'},
#   'number': 18154,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'Enable to restrict columns for pandas.read_parquet',
#   'updated_at': '2017-11-07T21:12:58Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18154',
#   'user': {'avatar_url': 'https://avatars2.githubusercontent.com/u/7143?v=4',
#    'events_url': 'https://api.github.com/users/hoffmann/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/hoffmann/followers',
#    'following_url': 'https://api.github.com/users/hoffmann/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/hoffmann/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/hoffmann',
#    'id': 7143,
#    'login': 'hoffmann',
#    'organizations_url': 'https://api.github.com/users/hoffmann/orgs',
#    'received_events_url': 'https://api.github.com/users/hoffmann/received_events',
#    'repos_url': 'https://api.github.com/users/hoffmann/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/hoffmann/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/hoffmann/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/hoffmann'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': 'Expecting lots and lots of flake8 complaints...',
#   'closed_at': None,
#   'comments': 2,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18151/comments',
#   'created_at': '2017-11-07T17:38:53Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18151/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/18151',
#   'id': 271920990,
#   'labels': [{'color': 'eb6420',
#     'default': False,
#     'id': 106935113,
#     'name': 'Style',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Style'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18151/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'number': 18151,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/18151.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/18151',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/18151.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/18151'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'lint import order',
#   'updated_at': '2017-11-07T19:18:47Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18151',
#   'user': {'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/jbrockmendel',
#    'id': 8078968,
#    'login': 'jbrockmendel',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/jbrockmendel'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': '- [ ] closes #18121 \r\n- [ ] tests added / passed\r\n- [ ] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18150/comments',
#   'created_at': '2017-11-07T16:20:45Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18150/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/18150',
#   'id': 271893614,
#   'labels': [{'color': '207de5',
#     'default': False,
#     'id': 211029535,
#     'name': 'Clean',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean'},
#    {'color': 'fbca04',
#     'default': False,
#     'id': 49094459,
#     'name': 'Internals',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Internals'},
#    {'color': 'eb6420',
#     'default': False,
#     'id': 106935113,
#     'name': 'Style',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Style'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18150/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'number': 18150,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/18150.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/18150',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/18150.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/18150'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'Fix 18121: Add .pxd linting to lint.sh',
#   'updated_at': '2017-11-07T18:09:40Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18150',
#   'user': {'avatar_url': 'https://avatars3.githubusercontent.com/u/5673050?v=4',
#    'events_url': 'https://api.github.com/users/ManrajGrover/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/ManrajGrover/followers',
#    'following_url': 'https://api.github.com/users/ManrajGrover/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/ManrajGrover/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/ManrajGrover',
#    'id': 5673050,
#    'login': 'ManrajGrover',
#    'organizations_url': 'https://api.github.com/users/ManrajGrover/orgs',
#    'received_events_url': 'https://api.github.com/users/ManrajGrover/received_events',
#    'repos_url': 'https://api.github.com/users/ManrajGrover/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/ManrajGrover/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/ManrajGrover/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/ManrajGrover'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'NONE',
#   'body': 'This pull request is to make PR #17677 easier and was requested by @jreback [here](https://github.com/pandas-dev/pandas/pull/17677#pullrequestreview-73974610)\r\n',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18148/comments',
#   'created_at': '2017-11-07T13:08:06Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18148/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/18148',
#   'id': 271825176,
#   'labels': [{'color': '207de5',
#     'default': False,
#     'id': 211029535,
#     'name': 'Clean',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean'},
#    {'color': 'fbca04',
#     'default': False,
#     'id': 49094459,
#     'name': 'Internals',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Internals'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18148/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'number': 18148,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/18148.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/18148',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/18148.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/18148'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'melt moved into its own module',
#   'updated_at': '2017-11-07T16:22:33Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18148',
#   'user': {'avatar_url': 'https://avatars1.githubusercontent.com/u/7226751?v=4',
#    'events_url': 'https://api.github.com/users/tdpetrou/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/tdpetrou/followers',
#    'following_url': 'https://api.github.com/users/tdpetrou/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/tdpetrou/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/tdpetrou',
#    'id': 7226751,
#    'login': 'tdpetrou',
#    'organizations_url': 'https://api.github.com/users/tdpetrou/orgs',
#    'received_events_url': 'https://api.github.com/users/tdpetrou/received_events',
#    'repos_url': 'https://api.github.com/users/tdpetrou/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/tdpetrou/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/tdpetrou/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/tdpetrou'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': 'What do we want out of our API docs? What are the current issues?\r\n\r\nI think we\'re (mostly) happy with `api.rst`: we manually list the classes and methods that we want to include the docs, grouped by topics of our choosing.\r\n\r\nI think we\'re unhappy with some aspects of the auto-genrated class pages.\r\n\r\nThe [hack](https://github.com/pandas-dev/pandas/blob/c176a3c29ccabe7e471fa0b76c6cc1ceeb9bcd77/doc/sphinxext/numpydoc/numpydoc.py#L45-L48) in our vendored `numpydoc.py` "fixing" the autosummary to not include a table of methods for certain classes. This avoids a ton of redundant pages with the parent class, but we can\'t call out important differences like `RangeIndex.start`\r\n\r\nA potential solution is to (somehow) whitelist the methods that are shown in the autogenerated docs for (specific) classes. Something like\r\n\r\n```\r\n.. autosummary:\r\n   :toctree: generated/\r\n   :template: magic_template\r\n   :members: start, stop, step,\r\n\r\n   RangeIndex\r\n```\r\n\r\nUnfortunately, I haven\'t found a clean way of doing this at the template level. I played with it a bit this weekend to no avail, but if that\'s what we want I\'ll keep trying.\r\n\r\nWe also have https://github.com/pandas-dev/pandas/issues/5218 (about documenting cython functions).\r\n\r\nAny other annoyances I\'m missing?',
#   'closed_at': None,
#   'comments': 0,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18147/comments',
#   'created_at': '2017-11-07T12:31:30Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18147/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/18147',
#   'id': 271815094,
#   'labels': [{'color': 'fbca04',
#     'default': False,
#     'id': 195647922,
#     'name': 'Difficulty Intermediate',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Difficulty%20Intermediate'},
#    {'color': '3465A4',
#     'default': False,
#     'id': 134699,
#     'name': 'Docs',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs'},
#    {'color': '006b75',
#     'default': False,
#     'id': 195648017,
#     'name': 'Effort Medium',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Effort%20Medium'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18147/labels{/name}',
#   'locked': False,
#   'milestone': {'closed_at': None,
#    'closed_issues': 228,
#    'created_at': '2015-01-13T10:53:19Z',
#    'creator': {'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'gravatar_id': '',
#     'html_url': 'https://github.com/jreback',
#     'id': 953992,
#     'login': 'jreback',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'site_admin': False,
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'type': 'User',
#     'url': 'https://api.github.com/users/jreback'},
#    'description': '',
#    'due_on': '2018-08-31T07:00:00Z',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'id': 933188,
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'number': 32,
#    'open_issues': 1248,
#    'state': 'open',
#    'title': 'Next Major Release',
#    'updated_at': '2017-11-07T20:56:44Z',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32'},
#   'number': 18147,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'API Docs Rework ',
#   'updated_at': '2017-11-07T12:31:46Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18147',
#   'user': {'avatar_url': 'https://avatars3.githubusercontent.com/u/1312546?v=4',
#    'events_url': 'https://api.github.com/users/TomAugspurger/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/TomAugspurger/followers',
#    'following_url': 'https://api.github.com/users/TomAugspurger/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/TomAugspurger/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/TomAugspurger',
#    'id': 1312546,
#    'login': 'TomAugspurger',
#    'organizations_url': 'https://api.github.com/users/TomAugspurger/orgs',
#    'received_events_url': 'https://api.github.com/users/TomAugspurger/received_events',
#    'repos_url': 'https://api.github.com/users/TomAugspurger/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/TomAugspurger/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/TomAugspurger/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/TomAugspurger'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': '`DataFrame.to_records()` outputs string columns with the `object` dtype, which is sometimes not efficient (e.g. for short, similar-length strings, or when storing with `np.save()`).  I wrote the following function to fix this:\r\n\r\n```\r\ndef to_records_plain(df):\r\n    """Return a NumPy recarray like df.to_records() but with strings stored as bytes, not objects.\r\n    This gives more compact storage and does not require pickling objects when saving to disk.\r\n    Assumes all object arrays in df are strings.\r\n\r\n    >>> df = pd.DataFrame({\'a\': [1, 2], \'b\': [0.5, 0.9], \'c\': [\'x\', \'yyy\']})\r\n    >>> to_records_plain(df)\r\n    rec.array([(0, 1,  0.5, b\'x\'), (1, 2,  0.9, b\'yyy\')], \r\n              dtype=[(\'index\', \'<i8\'), (\'a\', \'<i8\'), (\'b\', \'<f8\'), (\'c\', \'S3\')])\r\n    """\r\n    records = df.to_records()\r\n    descr = records.dtype.descr\r\n    for ii, (name, dtype) in enumerate(descr):\r\n        if dtype == \'|O\':\r\n            length = df[name].str.len().max()\r\n            descr[ii] = (name, \'S{}\'.format(length))\r\n\r\n    return records.astype(descr)\r\n```\r\n\r\nI suggest exposing something like this as an option in `DataFrame.to_records()`.  An option to convert to Unicode (`\'U\'`) too would be good too (NumPy\'s `\'S\'` is effectively `bytes` in Python 3).',
#   'closed_at': None,
#   'comments': 3,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18146/comments',
#   'created_at': '2017-11-07T02:05:22Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18146/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/18146',
#   'id': 271685639,
#   'labels': [{'color': 'e102d8',
#     'default': False,
#     'id': 31404521,
#     'name': 'Dtypes',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtypes'},
#    {'color': '4E9A06',
#     'default': False,
#     'id': 76812,
#     'name': 'Enhancement',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement'},
#    {'color': 'ededed',
#     'default': False,
#     'id': 13101118,
#     'name': 'Output-Formatting',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Output-Formatting'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18146/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'number': 18146,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'ENH: add to_records() option to output NumPy string dtypes, not objects',
#   'updated_at': '2017-11-07T16:46:22Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18146',
#   'user': {'avatar_url': 'https://avatars0.githubusercontent.com/u/1216791?v=4',
#    'events_url': 'https://api.github.com/users/jzwinck/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/jzwinck/followers',
#    'following_url': 'https://api.github.com/users/jzwinck/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jzwinck/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/jzwinck',
#    'id': 1216791,
#    'login': 'jzwinck',
#    'organizations_url': 'https://api.github.com/users/jzwinck/orgs',
#    'received_events_url': 'https://api.github.com/users/jzwinck/received_events',
#    'repos_url': 'https://api.github.com/users/jzwinck/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/jzwinck/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jzwinck/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/jzwinck'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': "The goal I have in mind is getting to the point where we can test (and measure coverage) tslibs in isolation.   That means isolating DataFrame and Series tests from everything else.\r\n\r\nThis PR doesn't change any tests and doesn't move anything across modules, just puts DataFrame and Series tests in their own classes.  Exactly what modules those belong in I haven't thought out.\r\n\r\nIf I did this right, it shouldn't have any overlap with other outstanding PRs.",
#   'closed_at': None,
#   'comments': 3,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18142/comments',
#   'created_at': '2017-11-06T16:32:58Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18142/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/18142',
#   'id': 271537969,
#   'labels': [{'color': '207de5',
#     'default': False,
#     'id': 211029535,
#     'name': 'Clean',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean'},
#    {'color': 'C4A000',
#     'default': False,
#     'id': 127685,
#     'name': 'Testing',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18142/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'number': 18142,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/18142.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/18142',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/18142.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/18142'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'Separate out non-scalar tests from scalar tests; move to ?? in follow-up',
#   'updated_at': '2017-11-07T21:34:38Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18142',
#   'user': {'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/jbrockmendel',
#    'id': 8078968,
#    'login': 'jbrockmendel',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/jbrockmendel'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'NONE',
#   'body': "I know that `pandas` makes use of some of the private interfaces in `dateutil` (and I'm hoping to start adding features so that this is no longer necessary), so I thought I'd give you a heads up about a proposed changed to the organization of the `parser` module that will change the location of some of the private interfaces.\r\n\r\nBasically `parser.py` will move to `parser/_parser.py`, and only the public parts will be imported into `parser/__init__.py`, as part of the introduction of a dedicated ISO-8601 parser. See PR dateutil/dateutil#489 for the current discussion.",
#   'closed_at': None,
#   'comments': 19,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18141/comments',
#   'created_at': '2017-11-06T15:56:52Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18141/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/18141',
#   'id': 271524753,
#   'labels': [{'color': 'd93f0b',
#     'default': False,
#     'id': 527603109,
#     'name': 'Dependencies',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dependencies'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18141/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'number': 18141,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'Forthcoming dateutil code reorganization',
#   'updated_at': '2017-11-08T00:48:01Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18141',
#   'user': {'avatar_url': 'https://avatars0.githubusercontent.com/u/1377457?v=4',
#    'events_url': 'https://api.github.com/users/pganssle/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/pganssle/followers',
#    'following_url': 'https://api.github.com/users/pganssle/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pganssle/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/pganssle',
#    'id': 1377457,
#    'login': 'pganssle',
#    'organizations_url': 'https://api.github.com/users/pganssle/orgs',
#    'received_events_url': 'https://api.github.com/users/pganssle/received_events',
#    'repos_url': 'https://api.github.com/users/pganssle/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/pganssle/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pganssle/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/pganssle'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'NONE',
#   'body': "panads version is 0.20.2\r\n\r\n```python\r\ndf=pd.DataFrame({'0':['x',np.nan,np.nan],'col':range(3)})\r\n     0  col\r\n0    x    0\r\n1  NaN    1\r\n2  NaN    2\r\n\r\ndf.set_index('0',inplace=True)\r\ndf\r\n     col\r\n0       \r\nx      0\r\nNaN    1\r\nNaN    2\r\n\r\n#df.drop(df.index[[0]])  #this can drop  reminded by TomAugspurger \r\ndf.drop(df.index[[1]])  #this cannot\r\n     col\r\n0       \r\nx      0\r\nNaN    1\r\nNaN    2\r\n\r\ndf.drop(df.index[[0,1]]) #drop all \r\nEmpty DataFrame\r\nColumns: [col]\r\nIndex: []\r\n\r\n\r\n```\r\nand if replace NaN(which is np.nan ) in the df with float('nan') , it will get other weirder results \r\n\r\ncould you please tell me what leads to the problem above? Thx",
#   'closed_at': None,
#   'comments': 1,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18139/comments',
#   'created_at': '2017-11-06T13:27:00Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18139/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/18139',
#   'id': 271474611,
#   'labels': [{'color': '207de5',
#     'default': False,
#     'id': 307649777,
#     'name': 'Needs Info',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18139/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'number': 18139,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': '.drop() reacts differently when lables changed',
#   'updated_at': '2017-11-06T15:56:48Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18139',
#   'user': {'avatar_url': 'https://avatars3.githubusercontent.com/u/20675486?v=4',
#    'events_url': 'https://api.github.com/users/lypro09539/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/lypro09539/followers',
#    'following_url': 'https://api.github.com/users/lypro09539/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lypro09539/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/lypro09539',
#    'id': 20675486,
#    'login': 'lypro09539',
#    'organizations_url': 'https://api.github.com/users/lypro09539/orgs',
#    'received_events_url': 'https://api.github.com/users/lypro09539/received_events',
#    'repos_url': 'https://api.github.com/users/lypro09539/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/lypro09539/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lypro09539/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/lypro09539'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'NONE',
#   'body': "#### Code Sample\r\n\r\n```\r\nimport pandas as pd\r\nfrom IPython.display import display\r\n\r\n# read some data for size 200,000 x 4\r\n\r\ndisplay(data.loc[:, ['reading']])  #25ms\r\ndisplay(data.reading.to_frame())  #25ms\r\ndisplay(data.reading) #3.53s\r\ns = data.reading\r\ndisplay(s) #3.32s possibly cached\r\nprint(data.reading) #9ms\r\nprint(data.loc[:, ['reading']]) # 15ms\r\n```\r\n#### Problem description\r\n\r\nIn the Jupyter notebook, displaying a `pd.Series` is VERY slow. It is displays quicker when kept as a `pd.DataFrame` but is of course more verbose.\r\n\r\n#### Expected Output\r\n\r\nA pd.Series display/print out at reasonable speeds.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit: None\r\npython: 3.5.4.final.0\r\npython-bits: 64\r\nOS: Windows\r\nOS-release: 7\r\nmachine: AMD64\r\nprocessor: Intel64 Family 6 Model 60 Stepping 3, GenuineIntel\r\nbyteorder: little\r\nLC_ALL: None\r\nLANG: None\r\nLOCALE: None.None\r\n\r\npandas: 0.21.0\r\npytest: 3.2.1\r\npip: 9.0.1\r\nsetuptools: 36.2.4\r\nCython: 0.26\r\nnumpy: 1.13.3\r\nscipy: 0.19.1\r\npyarrow: None\r\nxarray: None\r\nIPython: 5.3.0\r\nsphinx: 1.6.3\r\npatsy: 0.4.1\r\ndateutil: 2.6.1\r\npytz: 2017.3\r\nblosc: None\r\nbottleneck: 1.2.1\r\ntables: 3.4.2\r\nnumexpr: 2.6.2\r\nfeather: None\r\nmatplotlib: 2.0.0\r\nopenpyxl: 2.5.0a2\r\nxlrd: 1.0.0\r\nxlwt: 1.2.0\r\nxlsxwriter: 0.9.8\r\nlxml: 3.8.0\r\nbs4: 4.6.0\r\nhtml5lib: 0.9999999\r\nsqlalchemy: 1.1.13\r\npymysql: 0.7.9.None\r\npsycopg2: None\r\njinja2: 2.9.6\r\ns3fs: None\r\nfastparquet: None\r\npandas_gbq: None\r\npandas_datareader: 0.4.0\r\n\r\n</details>\r\n",
#   'closed_at': None,
#   'comments': 4,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18137/comments',
#   'created_at': '2017-11-06T09:49:30Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18137/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/18137',
#   'id': 271414227,
#   'labels': [{'color': '207de5',
#     'default': False,
#     'id': 307649777,
#     'name': 'Needs Info',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Info'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18137/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'number': 18137,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'Jupyter Notebook displays Series VERY slowly',
#   'updated_at': '2017-11-06T12:39:06Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18137',
#   'user': {'avatar_url': 'https://avatars3.githubusercontent.com/u/11645712?v=4',
#    'events_url': 'https://api.github.com/users/JoshuaC3/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/JoshuaC3/followers',
# ...
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Effort%20Medium'},
#    {'color': 'a10c02',
#     'default': False,
#     'id': 8935311,
#     'name': 'Performance',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance'},
#    {'color': '5319e7',
#     'default': False,
#     'id': 49597148,
#     'name': 'Timedelta',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timedelta'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18092/labels{/name}',
#   'locked': False,
#   'milestone': {'closed_at': None,
#    'closed_issues': 228,
#    'created_at': '2015-01-13T10:53:19Z',
#    'creator': {'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'gravatar_id': '',
#     'html_url': 'https://github.com/jreback',
#     'id': 953992,
#     'login': 'jreback',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'site_admin': False,
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'type': 'User',
#     'url': 'https://api.github.com/users/jreback'},
#    'description': '',
#    'due_on': '2018-08-31T07:00:00Z',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'id': 933188,
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'number': 32,
#    'open_issues': 1248,
#    'state': 'open',
#    'title': 'Next Major Release',
#    'updated_at': '2017-11-07T20:56:44Z',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32'},
#   'number': 18092,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'Pandas conversion of Timedelta is very slow',
#   'updated_at': '2017-11-07T02:54:33Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18092',
#   'user': {'avatar_url': 'https://avatars2.githubusercontent.com/u/708533?v=4',
#    'events_url': 'https://api.github.com/users/Stanpol/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/Stanpol/followers',
#    'following_url': 'https://api.github.com/users/Stanpol/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Stanpol/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/Stanpol',
#    'id': 708533,
#    'login': 'Stanpol',
#    'organizations_url': 'https://api.github.com/users/Stanpol/orgs',
#    'received_events_url': 'https://api.github.com/users/Stanpol/received_events',
#    'repos_url': 'https://api.github.com/users/Stanpol/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/Stanpol/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Stanpol/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/Stanpol'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'MEMBER',
#   'body': 'Implement `assert_not` as a way to check that assertions should fail (for methods more sophisticated than a simple bare `assert`).  Also takes the opportunity to remove several more `np.array_equal` assertions.\r\n\r\nFollow-up to #18047 ',
#   'closed_at': None,
#   'comments': 3,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18087/comments',
#   'created_at': '2017-11-03T05:37:40Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18087/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/18087',
#   'id': 270882866,
#   'labels': [{'color': 'C4A000',
#     'default': False,
#     'id': 127685,
#     'name': 'Testing',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18087/labels{/name}',
#   'locked': False,
#   'milestone': {'closed_at': None,
#    'closed_issues': 42,
#    'created_at': '2017-10-02T10:21:48Z',
#    'creator': {'avatar_url': 'https://avatars2.githubusercontent.com/u/953992?v=4',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'gravatar_id': '',
#     'html_url': 'https://github.com/jreback',
#     'id': 953992,
#     'login': 'jreback',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'site_admin': False,
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'type': 'User',
#     'url': 'https://api.github.com/users/jreback'},
#    'description': '',
#    'due_on': '2017-11-30T08:00:00Z',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/52',
#    'id': 2806806,
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/52/labels',
#    'number': 52,
#    'open_issues': 21,
#    'state': 'open',
#    'title': '0.21.1',
#    'updated_at': '2017-11-07T20:56:44Z',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/52'},
#   'number': 18087,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/18087.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/18087',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/18087.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/18087'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'TST: Implement assert_not in testing.py',
#   'updated_at': '2017-11-06T13:47:40Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18087',
#   'user': {'avatar_url': 'https://avatars0.githubusercontent.com/u/9273653?v=4',
#    'events_url': 'https://api.github.com/users/gfyoung/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/gfyoung/followers',
#    'following_url': 'https://api.github.com/users/gfyoung/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/gfyoung/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/gfyoung',
#    'id': 9273653,
#    'login': 'gfyoung',
#    'organizations_url': 'https://api.github.com/users/gfyoung/orgs',
#    'received_events_url': 'https://api.github.com/users/gfyoung/received_events',
#    'repos_url': 'https://api.github.com/users/gfyoung/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/gfyoung/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/gfyoung/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/gfyoung'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': "We're going to need `date_normalize` upstream of `tslib` before long, so this moves it to conversion.\r\n\r\nSimplifies repeated checking in `localize_tso`, closes #17944",
#   'closed_at': None,
#   'comments': 5,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18086/comments',
#   'created_at': '2017-11-03T03:57:15Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18086/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/18086',
#   'id': 270873388,
#   'labels': [{'color': '207de5',
#     'default': False,
#     'id': 211029535,
#     'name': 'Clean',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18086/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'number': 18086,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/18086.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/18086',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/18086.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/18086'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'Move normalization funcs up to conversion',
#   'updated_at': '2017-11-07T21:29:53Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18086',
#   'user': {'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/jbrockmendel',
#    'id': 8078968,
#    'login': 'jbrockmendel',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/jbrockmendel'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'CONTRIBUTOR',
#   'body': '- [ ] closes #xxxx\r\n- [ ] tests added / passed\r\n- [x] passes `git diff upstream/master -u -- "*.py" | flake8 --diff`\r\n- [ ] whatsnew entry\r\n',
#   'closed_at': None,
#   'comments': 10,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18085/comments',
#   'created_at': '2017-11-03T02:38:27Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18085/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/18085',
#   'id': 270864562,
#   'labels': [{'color': '207de5',
#     'default': False,
#     'id': 211029535,
#     'name': 'Clean',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Clean'},
#    {'color': 'fbca04',
#     'default': False,
#     'id': 49094459,
#     'name': 'Internals',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Internals'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18085/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'number': 18085,
#   'pull_request': {'diff_url': 'https://github.com/pandas-dev/pandas/pull/18085.diff',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/18085',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/18085.patch',
#    'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/18085'},
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'move implementation of Timedelta to tslibs.timedeltas',
#   'updated_at': '2017-11-08T00:25:52Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18085',
#   'user': {'avatar_url': 'https://avatars1.githubusercontent.com/u/8078968?v=4',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/jbrockmendel',
#    'id': 8078968,
#    'login': 'jbrockmendel',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/jbrockmendel'}},
#  {'assignee': None,
#   'assignees': [],
#   'author_association': 'NONE',
#   'body': "\r\n\r\n```python\r\nimport pandas as pd\r\n\r\ndat = {\r\n    'user': ['Aaron', 'Aaron', 'Bob', 'Bob', 'Cindy', 'Cindy'],\r\n    'likes': ['Apples', 'Bananas', 'Cherries', 'Dates', 'eggs', 'fruit'],\r\n    'vals': [1, 2, 3, 4, 5, 6]\r\n}\r\ndf = pd.DataFrame(dat)\r\n\r\n# This doesn't work and returns a like indexed NDFrame with each individual element.\r\ndf.groupby('user')['likes'].transform(list) \r\ndf.groupby('user')['likes'].transform(lambda s: list(s))\r\ndf.groupby('user')['likes'].transform(pd.Series.tolist)\r\ndf.groupby('user')['likes'].transform(lambda s: pd.Series.tolist(s))\r\n\r\n\r\n# This worked - but ideally, shouldn't require this much effort.  There seems to be a problem with Transform and iterables in the new API (I kind think i remember this working in .18...)\r\n\r\ndef pd_xform_list(_iter):\r\n    tmpList = []\r\n    for x in _iter:\r\n        tmpList.append(x)\r\n    return str(tmpList)\r\n    \r\ndf['groups'] = df.groupby('user')['likes'].transform(lambda k: pd_xform_list(k))\r\nfrom ast import literal_eval\r\n\r\ndf['groups'] = df['groups'].apply(lambda st: literal_eval(st))\r\ndf\r\n\r\n\r\n```\r\n\r\nWhen attempting to transform (pd.groupby.transform) into collections in pandas, the like NDFrame object returns the individual elements instead of a collection.  string to literal evaluation workaround must be implemented.  This functions normally with custom aggregation (groupby.agg) - but does not work correctly with groupby.transform.\r\n\r\nRegards,\r\n\r\n",
#   'closed_at': None,
#   'comments': 2,
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18084/comments',
#   'created_at': '2017-11-02T22:28:10Z',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18084/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/18084',
#   'id': 270828021,
#   'labels': [{'color': '729FCF',
#     'default': False,
#     'id': 233160,
#     'name': 'Groupby',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby'}],
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18084/labels{/name}',
#   'locked': False,
#   'milestone': None,
#   'number': 18084,
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'state': 'open',
#   'title': 'groupby.Transform Aggregation into Collections returns individual elements (unless added or string concatenated)',
#   'updated_at': '2017-11-03T10:04:34Z',
#   'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/18084',
#   'user': {'avatar_url': 'https://avatars1.githubusercontent.com/u/33333297?v=4',
#    'events_url': 'https://api.github.com/users/yvanaquino/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/yvanaquino/followers',
#    'following_url': 'https://api.github.com/users/yvanaquino/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/yvanaquino/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/yvanaquino',
#    'id': 33333297,
#    'login': 'yvanaquino',
#    'organizations_url': 'https://api.github.com/users/yvanaquino/orgs',
#    'received_events_url': 'https://api.github.com/users/yvanaquino/received_events',
#    'repos_url': 'https://api.github.com/users/yvanaquino/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/yvanaquino/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/yvanaquino/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/yvanaquino'}}]

# %%
issues = pd.DataFrame(data)
issues
# Out:
#    assignee assignees author_association  \
# 0      None        []               NONE
# 1      None        []        CONTRIBUTOR
# 2      None        []        CONTRIBUTOR
# 3      None        []               NONE
# 4      None        []               NONE
# 5      None        []        CONTRIBUTOR
# 6      None        []        CONTRIBUTOR
# 7      None        []               NONE
# 8      None        []        CONTRIBUTOR
# 9      None        []        CONTRIBUTOR
# 10     None        []        CONTRIBUTOR
# 11     None        []               NONE
# 12     None        []               NONE
# 13     None        []               NONE
# 14     None        []        CONTRIBUTOR
# 15     None        []               NONE
# 16     None        []        CONTRIBUTOR
# 17     None        []        CONTRIBUTOR
# 18     None        []        CONTRIBUTOR
# 19     None        []        CONTRIBUTOR
# 20     None        []        CONTRIBUTOR
# 21     None        []        CONTRIBUTOR
# 22     None        []               NONE
# 23     None        []        CONTRIBUTOR
# 24     None        []        CONTRIBUTOR
# 25     None        []               NONE
# 26     None        []             MEMBER
# 27     None        []        CONTRIBUTOR
# 28     None        []        CONTRIBUTOR
# 29     None        []               NONE
#
#                                                  body closed_at  comments  \
# 0   #### Code Sample, a copy-pastable example if p...      None         0
# 1                        try reg dateutil install\r\n      None         0
# 2   #### Code Sample, a copy-pastable example if p...      None         3
# 3   - [ x ] closes #18154\r\n- [ x ] tests added /...      None         2
# 4   #### Problem description\r\n\r\nIn pandas 0.21...      None         2
# 5     Expecting lots and lots of flake8 complaints...      None         2
# 6   - [ ] closes #18121 \r\n- [ ] tests added / pa...      None         0
# 7   This pull request is to make PR #17677 easier ...      None         0
# 8   What do we want out of our API docs? What are ...      None         0
# 9   `DataFrame.to_records()` outputs string column...      None         3
# 10  The goal I have in mind is getting to the poin...      None         3
# 11  I know that `pandas` makes use of some of the ...      None        19
# 12  panads version is 0.20.2\r\n\r\n```python\r\nd...      None         1
# 13  #### Code Sample\r\n\r\n```\r\nimport pandas a...      None         4
# 14  Start parametrizing arithmetic tests for Datet...      None         4
# 15  This issue is based on data from this [Stack O...      None         8
# 16  - _libs/window both includes "skiplist.pyx" an...      None         0
# 17  I *think* this is a very recent change in nump...      None         8
# 18                                                         None         0
# 19  no need to have the branching in setup.py we a...      None         3
# 20  - [ ] closes #xxxx\r\n- [ ] tests added / pass...      None        15
# 21  ```python\r\nIn [1]: import pandas as pd\r\n\r...      None         2
# 22  This looks really messy, it's not difficult to...      None         3
# 23  - [ ] closes #17673\r\n- [x] tests added / pas...      None         3
# 24  - [X] closes #12860\r\n- [X] tests added / pas...      None         6
# 25  #### Code Sample, a copy-pastable example if p...      None         9
# 26  Implement `assert_not` as a way to check that ...      None         3
# 27  We're going to need `date_normalize` upstream ...      None         5
# 28  - [ ] closes #xxxx\r\n- [ ] tests added / pass...      None        10
# 29  \r\n\r\n```python\r\nimport pandas as pd\r\n\r...      None         2
#
#                                          comments_url            created_at  \
# 0   https://api.github.com/repos/pandas-dev/pandas...  2017-11-08T00:11:37Z
# 1   https://api.github.com/repos/pandas-dev/pandas...  2017-11-07T21:13:26Z
# 2   https://api.github.com/repos/pandas-dev/pandas...  2017-11-07T20:19:00Z
# 3   https://api.github.com/repos/pandas-dev/pandas...  2017-11-07T20:09:57Z
# 4   https://api.github.com/repos/pandas-dev/pandas...  2017-11-07T20:08:35Z
# 5   https://api.github.com/repos/pandas-dev/pandas...  2017-11-07T17:38:53Z
# 6   https://api.github.com/repos/pandas-dev/pandas...  2017-11-07T16:20:45Z
# 7   https://api.github.com/repos/pandas-dev/pandas...  2017-11-07T13:08:06Z
# 8   https://api.github.com/repos/pandas-dev/pandas...  2017-11-07T12:31:30Z
# 9   https://api.github.com/repos/pandas-dev/pandas...  2017-11-07T02:05:22Z
# 10  https://api.github.com/repos/pandas-dev/pandas...  2017-11-06T16:32:58Z
# 11  https://api.github.com/repos/pandas-dev/pandas...  2017-11-06T15:56:52Z
# 12  https://api.github.com/repos/pandas-dev/pandas...  2017-11-06T13:27:00Z
# 13  https://api.github.com/repos/pandas-dev/pandas...  2017-11-06T09:49:30Z
# 14  https://api.github.com/repos/pandas-dev/pandas...  2017-11-06T05:03:25Z
# 15  https://api.github.com/repos/pandas-dev/pandas...  2017-11-06T02:06:47Z
# 16  https://api.github.com/repos/pandas-dev/pandas...  2017-11-05T17:13:49Z
# 17  https://api.github.com/repos/pandas-dev/pandas...  2017-11-05T12:37:52Z
# 18  https://api.github.com/repos/pandas-dev/pandas...  2017-11-05T11:01:12Z
# 19  https://api.github.com/repos/pandas-dev/pandas...  2017-11-04T19:52:07Z
# 20  https://api.github.com/repos/pandas-dev/pandas...  2017-11-04T19:49:03Z
# 21  https://api.github.com/repos/pandas-dev/pandas...  2017-11-04T19:03:03Z
# 22  https://api.github.com/repos/pandas-dev/pandas...  2017-11-04T02:52:31Z
# 23  https://api.github.com/repos/pandas-dev/pandas...  2017-11-04T01:25:32Z
# 24  https://api.github.com/repos/pandas-dev/pandas...  2017-11-03T23:13:10Z
# 25  https://api.github.com/repos/pandas-dev/pandas...  2017-11-03T12:49:26Z
# 26  https://api.github.com/repos/pandas-dev/pandas...  2017-11-03T05:37:40Z
# 27  https://api.github.com/repos/pandas-dev/pandas...  2017-11-03T03:57:15Z
# 28  https://api.github.com/repos/pandas-dev/pandas...  2017-11-03T02:38:27Z
# 29  https://api.github.com/repos/pandas-dev/pandas...  2017-11-02T22:28:10Z
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url  \
# 0   https://github.com/pandas-dev/pandas/issues/18159
# 1     https://github.com/pandas-dev/pandas/pull/18157
# 2   https://github.com/pandas-dev/pandas/issues/18156
# 3     https://github.com/pandas-dev/pandas/pull/18155
# 4   https://github.com/pandas-dev/pandas/issues/18154
# 5     https://github.com/pandas-dev/pandas/pull/18151
# 6     https://github.com/pandas-dev/pandas/pull/18150
# 7     https://github.com/pandas-dev/pandas/pull/18148
# 8   https://github.com/pandas-dev/pandas/issues/18147
# 9   https://github.com/pandas-dev/pandas/issues/18146
# 10    https://github.com/pandas-dev/pandas/pull/18142
# 11  https://github.com/pandas-dev/pandas/issues/18141
# 12  https://github.com/pandas-dev/pandas/issues/18139
# 13  https://github.com/pandas-dev/pandas/issues/18137
# 14    https://github.com/pandas-dev/pandas/pull/18133
# 15  https://github.com/pandas-dev/pandas/issues/18129
# 16  https://github.com/pandas-dev/pandas/issues/18125
# 17  https://github.com/pandas-dev/pandas/issues/18123
# 18  https://github.com/pandas-dev/pandas/issues/18121
# 19  https://github.com/pandas-dev/pandas/issues/18113
# 20    https://github.com/pandas-dev/pandas/pull/18112
# 21  https://github.com/pandas-dev/pandas/issues/18111
# 22  https://github.com/pandas-dev/pandas/issues/18103
# 23    https://github.com/pandas-dev/pandas/pull/18100
# 24    https://github.com/pandas-dev/pandas/pull/18099
# 25  https://github.com/pandas-dev/pandas/issues/18092
# 26    https://github.com/pandas-dev/pandas/pull/18087
# 27    https://github.com/pandas-dev/pandas/pull/18086
# 28    https://github.com/pandas-dev/pandas/pull/18085
# 29  https://github.com/pandas-dev/pandas/issues/18084
#
#                           ...                          locked  \
# 0                         ...                           False
# 1                         ...                           False
# 2                         ...                           False
# 3                         ...                           False
# 4                         ...                           False
# 5                         ...                           False
# 6                         ...                           False
# 7                         ...                           False
# 8                         ...                           False
# 9                         ...                           False
# 10                        ...                           False
# 11                        ...                           False
# 12                        ...                           False
# 13                        ...                           False
# 14                        ...                           False
# 15                        ...                           False
# 16                        ...                           False
# 17                        ...                           False
# 18                        ...                           False
# 19                        ...                           False
# 20                        ...                           False
# 21                        ...                           False
# 22                        ...                           False
# 23                        ...                           False
# 24                        ...                           False
# 25                        ...                           False
# 26                        ...                           False
# 27                        ...                           False
# 28                        ...                           False
# 29                        ...                           False
#
#                                             milestone number  \
# 0                                                None  18159
# 1                                                None  18157
# 2   {'url': 'https://api.github.com/repos/pandas-d...  18156
# 3                                                None  18155
# 4   {'url': 'https://api.github.com/repos/pandas-d...  18154
# 5                                                None  18151
# 6                                                None  18150
# 7                                                None  18148
# 8   {'url': 'https://api.github.com/repos/pandas-d...  18147
# 9                                                None  18146
# 10                                               None  18142
# 11                                               None  18141
# 12                                               None  18139
# 13                                               None  18137
# 14                                               None  18133
# 15                                               None  18129
# 16  {'url': 'https://api.github.com/repos/pandas-d...  18125
# 17  {'url': 'https://api.github.com/repos/pandas-d...  18123
# 18  {'url': 'https://api.github.com/repos/pandas-d...  18121
# 19  {'url': 'https://api.github.com/repos/pandas-d...  18113
# 20  {'url': 'https://api.github.com/repos/pandas-d...  18112
# 21  {'url': 'https://api.github.com/repos/pandas-d...  18111
# 22                                               None  18103
# 23                                               None  18100
# 24                                               None  18099
# 25  {'url': 'https://api.github.com/repos/pandas-d...  18092
# 26  {'url': 'https://api.github.com/repos/pandas-d...  18087
# 27                                               None  18086
# 28                                               None  18085
# 29                                               None  18084
#
#                                          pull_request  \
# 0                                                 NaN
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2                                                 NaN
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4                                                 NaN
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8                                                 NaN
# 9                                                 NaN
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21                                                NaN
# 22                                                NaN
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25                                                NaN
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29                                                NaN
#
#                                     repository_url  state  \
# 0   https://api.github.com/repos/pandas-dev/pandas   open
# 1   https://api.github.com/repos/pandas-dev/pandas   open
# 2   https://api.github.com/repos/pandas-dev/pandas   open
# 3   https://api.github.com/repos/pandas-dev/pandas   open
# 4   https://api.github.com/repos/pandas-dev/pandas   open
# 5   https://api.github.com/repos/pandas-dev/pandas   open
# 6   https://api.github.com/repos/pandas-dev/pandas   open
# 7   https://api.github.com/repos/pandas-dev/pandas   open
# 8   https://api.github.com/repos/pandas-dev/pandas   open
# 9   https://api.github.com/repos/pandas-dev/pandas   open
# 10  https://api.github.com/repos/pandas-dev/pandas   open
# 11  https://api.github.com/repos/pandas-dev/pandas   open
# 12  https://api.github.com/repos/pandas-dev/pandas   open
# 13  https://api.github.com/repos/pandas-dev/pandas   open
# 14  https://api.github.com/repos/pandas-dev/pandas   open
# 15  https://api.github.com/repos/pandas-dev/pandas   open
# 16  https://api.github.com/repos/pandas-dev/pandas   open
# 17  https://api.github.com/repos/pandas-dev/pandas   open
# 18  https://api.github.com/repos/pandas-dev/pandas   open
# 19  https://api.github.com/repos/pandas-dev/pandas   open
# 20  https://api.github.com/repos/pandas-dev/pandas   open
# 21  https://api.github.com/repos/pandas-dev/pandas   open
# 22  https://api.github.com/repos/pandas-dev/pandas   open
# 23  https://api.github.com/repos/pandas-dev/pandas   open
# 24  https://api.github.com/repos/pandas-dev/pandas   open
# 25  https://api.github.com/repos/pandas-dev/pandas   open
# 26  https://api.github.com/repos/pandas-dev/pandas   open
# 27  https://api.github.com/repos/pandas-dev/pandas   open
# 28  https://api.github.com/repos/pandas-dev/pandas   open
# 29  https://api.github.com/repos/pandas-dev/pandas   open
#
#                                                 title            updated_at  \
# 0   BUG: fillna maximum recursion depth exceeded i...  2017-11-08T00:11:37Z
# 1      WIP/CI: don't show miniconda output on install  2017-11-07T21:40:52Z
# 2        Minor doc issue in to_parquet(engine='auto')  2017-11-07T20:53:32Z
# 3    restrict columns to read for pandas.read_parquet  2017-11-07T21:17:48Z
# 4   Enable to restrict columns for pandas.read_par...  2017-11-07T21:12:58Z
# 5                                   lint import order  2017-11-07T19:18:47Z
# 6              Fix 18121: Add .pxd linting to lint.sh  2017-11-07T18:09:40Z
# 7                      melt moved into its own module  2017-11-07T16:22:33Z
# 8                                    API Docs Rework   2017-11-07T12:31:46Z
# 9   ENH: add to_records() option to output NumPy s...  2017-11-07T16:46:22Z
# 10  Separate out non-scalar tests from scalar test...  2017-11-07T21:34:38Z
# 11           Forthcoming dateutil code reorganization  2017-11-08T00:48:01Z
# 12     .drop() reacts differently when lables changed  2017-11-06T15:56:48Z
# 13       Jupyter Notebook displays Series VERY slowly  2017-11-06T12:39:06Z
# 14         parametrize the first few arithmetic tests  2017-11-06T22:33:06Z
# 15  DataFrame.rolling does nothing when values are...  2017-11-06T23:07:44Z
# 16          src dependencies/cleanup issue aggregator  2017-11-05T18:14:05Z
# 17                        TST: compat with numpy 1.14  2017-11-06T00:26:11Z
# 18                    CI: add .pxd linting to lint.sh  2017-11-05T11:01:12Z
# 19  BLD: since we already use setuptools, let's re...  2017-11-07T14:06:27Z
# 20            explicitly set 'include' to numpy_incls  2017-11-07T23:20:33Z
# 21    BUG: pd.unique treats 0 and False as equivalent  2017-11-05T00:16:08Z
# 22  Behavior of new df.agg, df.transform and df.ap...  2017-11-04T21:40:48Z
# 23                     DOC: Improve replace docstring  2017-11-05T04:41:19Z
# 24        ENH: Implement DataFrame.astype('category')  2017-11-05T12:23:46Z
# 25        Pandas conversion of Timedelta is very slow  2017-11-07T02:54:33Z
# 26            TST: Implement assert_not in testing.py  2017-11-06T13:47:40Z
# 27          Move normalization funcs up to conversion  2017-11-07T21:29:53Z
# 28  move implementation of Timedelta to tslibs.tim...  2017-11-08T00:25:52Z
# 29  groupby.Transform Aggregation into Collections...  2017-11-03T10:04:34Z
#
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                                  user
# 0   {'login': 'llchan', 'id': 51099, 'avatar_url':...
# 1   {'login': 'jreback', 'id': 953992, 'avatar_url...
# 2   {'login': 'MaximilianR', 'id': 5635139, 'avata...
# 3   {'login': 'hoffmann', 'id': 7143, 'avatar_url'...
# 4   {'login': 'hoffmann', 'id': 7143, 'avatar_url'...
# 5   {'login': 'jbrockmendel', 'id': 8078968, 'avat...
# 6   {'login': 'ManrajGrover', 'id': 5673050, 'avat...
# 7   {'login': 'tdpetrou', 'id': 7226751, 'avatar_u...
# 8   {'login': 'TomAugspurger', 'id': 1312546, 'ava...
# 9   {'login': 'jzwinck', 'id': 1216791, 'avatar_ur...
# 10  {'login': 'jbrockmendel', 'id': 8078968, 'avat...
# 11  {'login': 'pganssle', 'id': 1377457, 'avatar_u...
# 12  {'login': 'lypro09539', 'id': 20675486, 'avata...
# 13  {'login': 'JoshuaC3', 'id': 11645712, 'avatar_...
# 14  {'login': 'jbrockmendel', 'id': 8078968, 'avat...
# 15  {'login': 'tdpetrou', 'id': 7226751, 'avatar_u...
# 16  {'login': 'jbrockmendel', 'id': 8078968, 'avat...
# 17  {'login': 'jreback', 'id': 953992, 'avatar_url...
# 18  {'login': 'jreback', 'id': 953992, 'avatar_url...
# 19  {'login': 'jreback', 'id': 953992, 'avatar_url...
# 20  {'login': 'jbrockmendel', 'id': 8078968, 'avat...
# 21  {'login': 'mroeschke', 'id': 10647082, 'avatar...
# 22  {'login': 'memeplex', 'id': 2845433, 'avatar_u...
# 23  {'login': 'reidy-p', 'id': 21114125, 'avatar_u...
# 24  {'login': 'jschendel', 'id': 5332445, 'avatar_...
# 25  {'login': 'Stanpol', 'id': 708533, 'avatar_url...
# 26  {'login': 'gfyoung', 'id': 9273653, 'avatar_ur...
# 27  {'login': 'jbrockmendel', 'id': 8078968, 'avat...
# 28  {'login': 'jbrockmendel', 'id': 8078968, 'avat...
# 29  {'login': 'yvanaquino', 'id': 33333297, 'avata...
#
# [30 rows x 23 columns]

# %%
issues[['number', 'title']]
# Out:
#     number                                              title
# 0    18159  BUG: fillna maximum recursion depth exceeded i...
# 1    18157     WIP/CI: don't show miniconda output on install
# 2    18156       Minor doc issue in to_parquet(engine='auto')
# 3    18155   restrict columns to read for pandas.read_parquet
# 4    18154  Enable to restrict columns for pandas.read_par...
# 5    18151                                  lint import order
# 6    18150             Fix 18121: Add .pxd linting to lint.sh
# 7    18148                     melt moved into its own module
# 8    18147                                   API Docs Rework
# 9    18146  ENH: add to_records() option to output NumPy s...
# 10   18142  Separate out non-scalar tests from scalar test...
# 11   18141           Forthcoming dateutil code reorganization
# 12   18139     .drop() reacts differently when lables changed
# 13   18137       Jupyter Notebook displays Series VERY slowly
# 14   18133         parametrize the first few arithmetic tests
# 15   18129  DataFrame.rolling does nothing when values are...
# 16   18125          src dependencies/cleanup issue aggregator
# 17   18123                        TST: compat with numpy 1.14
# 18   18121                    CI: add .pxd linting to lint.sh
# 19   18113  BLD: since we already use setuptools, let's re...
# 20   18112            explicitly set 'include' to numpy_incls
# 21   18111    BUG: pd.unique treats 0 and False as equivalent
# 22   18103  Behavior of new df.agg, df.transform and df.ap...
# 23   18100                     DOC: Improve replace docstring
# 24   18099        ENH: Implement DataFrame.astype('category')
# 25   18092        Pandas conversion of Timedelta is very slow
# 26   18087            TST: Implement assert_not in testing.py
# 27   18086          Move normalization funcs up to conversion
# 28   18085  move implementation of Timedelta to tslibs.tim...
# 29   18084  groupby.Transform Aggregation into Collections...

# %% [markdown]
# ## Interating with Databases

# %%
import sqlalchemy as sqla
db = sqla.create_engine('sqlite:///mydata.sqlite')

pd.read_sql('select * from test', db)
